# %% [markdown]
# # Importing Basic Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes_dataset.csv')

# %%
df
# Out:
#        age  gender ethnicity education_level  income_level employment_status  \
# 0       58    Male     Asian      Highschool  Lower-Middle          Employed
# 1       48  Female     White      Highschool        Middle          Employed
# 2       60    Male  Hispanic      Highschool        Middle        Unemployed
# 3       74  Female     Black      Highschool           Low           Retired
# 4       46    Male     White        Graduate        Middle           Retired
# ...    ...     ...       ...             ...           ...               ...
# 99995   46    Male     Other        Graduate  Upper-Middle        Unemployed
# 99996   41  Female     White        Graduate        Middle          Employed
# 99997   57  Female     Black       No formal  Upper-Middle          Employed
# 99998   47  Female     Black      Highschool  Lower-Middle           Retired
# 99999   52  Female     White    Postgraduate        Middle          Employed
#
#       smoking_status  alcohol_consumption_per_week  \
# 0              Never                             0
# 1             Former                             1
# 2              Never                             1
# 3              Never                             0
# 4              Never                             1
# ...              ...                           ...
# 99995         Former                             1
# 99996          Never                             3
# 99997         Former                             4
# 99998          Never                             3
# 99999          Never                             1
#
#        physical_activity_minutes_per_week  diet_score  ...  hdl_cholesterol  \
# 0                                     215         5.7  ...               41
# 1                                     143         6.7  ...               55
# 2                                      57         6.4  ...               66
# 3                                      49         3.4  ...               50
# 4                                     109         7.2  ...               52
# ...                                   ...         ...  ...              ...
# 99995                                 136         8.3  ...               45
# 99996                                  76         8.8  ...               55
# 99997                                 121         9.9  ...               50
# 99998                                  52         5.9  ...               68
# 99999                                 248         2.7  ...               31
#
#        ldl_cholesterol  triglycerides  glucose_fasting  glucose_postprandial  \
# 0                  160            145              136                   236
# 1                   50             30               93                   150
# 2                   99             36              118                   195
# 3                   79            140              139                   253
# 4                  125            160              137                   184
# ...                ...            ...              ...                   ...
# 99995              150            116              113                   109
# 99996              123            146               96                   146
# 99997              111            184               93                   132
# 99998               91            116              106                   117
# 99999              183             87               91                   142
#
#        insulin_level  hba1c  diabetes_risk_score  diabetes_stage  \
# 0               6.36   8.18                 29.6          Type 2
# 1               2.00   5.63                 23.0     No Diabetes
# 2               5.07   7.51                 44.7          Type 2
# 3               5.28   9.03                 38.2          Type 2
# 4              12.74   7.20                 23.5          Type 2
# ...              ...    ...                  ...             ...
# 99995          14.58   5.55                 26.0    Pre-Diabetes
# 99996           9.02   5.97                 24.4    Pre-Diabetes
# 99997           2.57   5.21                 27.6     No Diabetes
# 99998           9.81   5.53                 26.4    Pre-Diabetes
# 99999          15.93   5.73                 27.9    Pre-Diabetes
#
#        diagnosed_diabetes
# 0                       1
# 1                       0
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 99995                   0
# 99996                   0
# 99997                   0
# 99998                   0
# 99999                   0
#
# [100000 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['age', 'gender', 'ethnicity', 'education_level', 'income_level',
#        'employment_status', 'smoking_status', 'alcohol_consumption_per_week',
#        'physical_activity_minutes_per_week', 'diet_score',
#        'sleep_hours_per_day', 'screen_time_hours_per_day',
#        'family_history_diabetes', 'hypertension_history',
#        'cardiovascular_history', 'bmi', 'waist_to_hip_ratio', 'systolic_bp',
#        'diastolic_bp', 'heart_rate', 'cholesterol_total', 'hdl_cholesterol',
#        'ldl_cholesterol', 'triglycerides', 'glucose_fasting',
#        'glucose_postprandial', 'insulin_level', 'hba1c', 'diabetes_risk_score',
#        'diabetes_stage', 'diagnosed_diabetes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 100000 non-null  int64
#  1   gender                              100000 non-null  object
#  2   ethnicity                           100000 non-null  object
#  3   education_level                     100000 non-null  object
#  4   income_level                        100000 non-null  object
#  5   employment_status                   100000 non-null  object
#  6   smoking_status                      100000 non-null  object
#  7   alcohol_consumption_per_week        100000 non-null  int64
#  8   physical_activity_minutes_per_week  100000 non-null  int64
#  9   diet_score                          100000 non-null  float64
#  10  sleep_hours_per_day                 100000 non-null  float64
#  11  screen_time_hours_per_day           100000 non-null  float64
#  12  family_history_diabetes             100000 non-null  int64
#  13  hypertension_history                100000 non-null  int64
#  14  cardiovascular_history              100000 non-null  int64
#  15  bmi                                 100000 non-null  float64
#  16  waist_to_hip_ratio                  100000 non-null  float64
#  17  systolic_bp                         100000 non-null  int64
#  18  diastolic_bp                        100000 non-null  int64
#  19  heart_rate                          100000 non-null  int64
#  20  cholesterol_total                   100000 non-null  int64
#  21  hdl_cholesterol                     100000 non-null  int64
#  22  ldl_cholesterol                     100000 non-null  int64
#  23  triglycerides                       100000 non-null  int64
#  24  glucose_fasting                     100000 non-null  int64
#  25  glucose_postprandial                100000 non-null  int64
#  26  insulin_level                       100000 non-null  float64
#  27  hba1c                               100000 non-null  float64
#  28  diabetes_risk_score                 100000 non-null  float64
#  29  diabetes_stage                      100000 non-null  object
#  30  diagnosed_diabetes                  100000 non-null  int64
# dtypes: float64(8), int64(16), object(7)
# memory usage: 23.7+ MB

# %%
X=df.drop(['diagnosed_diabetes','diabetes_risk_score','diabetes_stage'], axis=1)
y=df['diagnosed_diabetes']

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.33 , random_state=42)

# %%
categorical_columns = X.select_dtypes(include=['object','string']).columns
categorical_columns
# Out:
# Index(['gender', 'ethnicity', 'education_level', 'income_level',
#        'employment_status', 'smoking_status'],
#       dtype='object')

# %%
numerical_columns = X.select_dtypes(include=['int64' , 'float64']).columns
numerical_columns
# Out:
# Index(['age', 'alcohol_consumption_per_week',
#        'physical_activity_minutes_per_week', 'diet_score',
#        'sleep_hours_per_day', 'screen_time_hours_per_day',
#        'family_history_diabetes', 'hypertension_history',
#        'cardiovascular_history', 'bmi', 'waist_to_hip_ratio', 'systolic_bp',
#        'diastolic_bp', 'heart_rate', 'cholesterol_total', 'hdl_cholesterol',
#        'ldl_cholesterol', 'triglycerides', 'glucose_fasting',
#        'glucose_postprandial', 'insulin_level', 'hba1c'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering Automation

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer  ## for handling missing values
from sklearn.preprocessing import StandardScaler  ## for feature scaling
from sklearn.preprocessing import OneHotEncoder   ## for categorical to numerical
from sklearn.compose import ColumnTransformer

# %%
## Numerical Pipeline
num_pipeline = Pipeline(
    steps=[
        ('imputer' , SimpleImputer(strategy='median')),
        ('scaler' , StandardScaler())
    ]
)

# %%
## Categorical Pipeline
cat_pipeline = Pipeline(
    steps=[
        ('imputer' , SimpleImputer(strategy='most_frequent')),
        ('onehotencoder' , OneHotEncoder())
    ]
)

# %%
### Now both these pieline have to be combined using ColumnTransformer

preprocessor = ColumnTransformer([
    ('num_pipeline', num_pipeline , numerical_columns),
    ('cat_pipeline' , cat_pipeline , categorical_columns)
])

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
# Using different Algorithms

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
### Models

models = {
    'RandomForest':RandomForestClassifier(),
    'DecisionTree':DecisionTreeClassifier(),
    'LogisticRegression':LogisticRegression(),
    'SVC':SVC(),
    'GaussianNB':GaussianNB()
    
}

# %%
from sklearn.metrics import accuracy_score

# %%
### Now we write a function to evaluate our model

def evaluate_model(X_train , y_train , X_test , y_test):
    score={}
    for i in range(len(models)):
        model = list(models.values())[i]   ## we are basiucally converting the models named dictionary and taking its values and fit our training and testing data into it


        ## Fitting into model
        model.fit(X_train , y_train)

        ## Predicting testing data

        y_test_pred = model.predict(X_test)

        ## Predicting model accuracy
        test_model_score = accuracy_score(y_test_pred , y_test)

        score[list(models.keys())[i]] = test_model_score

    return score

# %%
evaluate_model(X_train , y_train , X_test , y_test)
# Out:
# {'RandomForest': 0.9226969696969697,
#  'DecisionTree': 0.8638181818181818,
#  'LogisticRegression': 0.8583939393939394,
#  'SVC': 0.8916363636363637,
#  'GaussianNB': 0.856}

# %%
## We clearly see RandomForestClassifier has highest accuracy score so we apply that and do its HyperParameter Tuning

classifier = RandomForestClassifier()

# %% [markdown]
# # Hyperparameter Tuning

# %%
parameters = {
    'n_estimators':[10,20,30],
    'criterion':['gini', 'entropy', 'log_loss'],
    'max_depth':range(1,4),
    'max_features':['sqrt', 'log2', None],
}

# %%
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV

cv1 = GridSearchCV(classifier , param_grid=parameters , cv=5 , verbose=3)
cv1.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=10;, score=0.864 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=10;, score=0.601 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=10;, score=0.601 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=10;, score=0.878 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=10;, score=0.635 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=20;, score=0.653 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=20;, score=0.708 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=20;, score=0.897 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=20;, score=0.806 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=20;, score=0.748 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=30;, score=0.825 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=30;, score=0.829 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=30;, score=0.810 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=30;, score=0.812 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=30;, score=0.601 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=10;, score=0.778 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=10;, score=0.601 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=10;, score=0.616 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=10;, score=0.601 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=10;, score=0.805 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=20;, score=0.678 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=20;, score=0.601 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=20;, score=0.617 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=20;, score=0.807 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=20;, score=0.601 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=30;, score=0.840 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=30;, score=0.786 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=30;, score=0.780 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=30;, score=0.604 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=log2, n_estimators=30;, score=0.601 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=10;, score=0.911 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=10;, score=0.909 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=10;, score=0.907 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=10;, score=0.912 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=10;, score=0.911 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=20;, score=0.911 total time=   1.5s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=20;, score=0.909 total time=   1.5s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=20;, score=0.907 total time=   1.4s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=20;, score=0.912 total time=   1.5s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=20;, score=0.911 total time=   1.7s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=30;, score=0.911 total time=   2.7s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=30;, score=0.909 total time=   2.4s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=30;, score=0.907 total time=   2.6s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=30;, score=0.912 total time=   2.6s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=None, n_estimators=30;, score=0.911 total time=   2.4s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.852 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.873 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.858 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.884 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=20;, score=0.874 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=20;, score=0.896 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=20;, score=0.864 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=20;, score=0.898 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=20;, score=0.911 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=30;, score=0.860 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=30;, score=0.862 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=30;, score=0.863 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=30;, score=0.901 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=30;, score=0.842 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.841 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.863 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.815 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.805 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.857 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=20;, score=0.858 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=20;, score=0.841 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=20;, score=0.865 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=20;, score=0.877 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=20;, score=0.831 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=30;, score=0.868 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=30;, score=0.863 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=30;, score=0.808 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=30;, score=0.841 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=30;, score=0.879 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=10;, score=0.922 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=10;, score=0.920 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=10;, score=0.917 total time=   1.2s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=10;, score=0.920 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=10;, score=0.922 total time=   1.1s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=20;, score=0.922 total time=   2.1s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=20;, score=0.920 total time=   2.1s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=20;, score=0.917 total time=   2.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=20;, score=0.920 total time=   2.1s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=20;, score=0.922 total time=   2.4s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=30;, score=0.922 total time=   3.7s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=30;, score=0.920 total time=   3.2s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=30;, score=0.917 total time=   3.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=30;, score=0.920 total time=   3.3s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=None, n_estimators=30;, score=0.922 total time=   3.8s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.875 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.881 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.879 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.897 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.905 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=20;, score=0.903 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=20;, score=0.907 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=20;, score=0.902 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=20;, score=0.844 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=20;, score=0.898 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=30;, score=0.906 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=30;, score=0.880 total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=30;, score=0.885 total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=30;, score=0.899 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=30;, score=0.894 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=10;, score=0

# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=10;, score=0.904 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=10;, score=0.906 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=10;, score=0.862 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=10;, score=0.902 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=20;, score=0.886 total time=   0.8s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=20;, score=0.859 total time=   0.8s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=20;, score=0.886 total time=   0.8s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=20;, score=0.909 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=20;, score=0.882 total time=   0.8s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=30;, score=0.916 total time=   1.2s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=30;, score=0.888 total time=   1.2s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=30;, score=0.896 total time=   1.2s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=30;, score=0.896 total time=   1.1s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=30;, score=0.889 total time=   1.1s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=10;, score=0.922 total time=   1.6s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=10;, score=0.920 total time=   1.6s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=10;, score=0.917 total time=   1.6s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=10;, score=0.920 total time=   1.6s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=10;, score=0.922 total time=   1.6s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=20;, score=0.922 total time=   3.5s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=20;, score=0.920 total time=   3.3s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=20;, score=0.917 total time=   3.3s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=20;, score=0.920 total time=   3.4s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=20;, score=0.922 total time=   3.5s
# [CV 1/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=30;, score=0.922 total time=   5.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=30;, score=0.920 total time=   4.9s
# [CV 3/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=30;, score=0.917 total time=   5.1s
# [CV 4/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=30;, score=0.920 total time=   5.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=30;, score=0.922 total time=   5.0s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': range(1, 4),
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 20, 30]},
#              verbose=3)

# %%
y_prediction = cv1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_prediction , y_test)
print(score)
# Out:
# 0.9229090909090909

# %%
cv1.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'n_estimators': 10}

# %% [markdown]
# # Now we do Model Serialization( Saving and Loading)

# %%
import joblib
import os

# %%
print("Starting save process")
# Out:
# Starting save process

# %%
joblib.dump(preprocessor , 'diabetes_preprocessor.pkl')
# Out:
# ['diabetes_preprocessor.pkl']

# %%
print("1. Preprocessor saved as 'diabetes_preprocessor.pkl'")
# Out:
# 1. Preprocessor saved as 'diabetes_preprocessor.pkl'

# %%
joblib.dump(cv1.best_estimator_ , 'diabetes_model.pkl')
# Out:
# ['diabetes_model.pkl']

# %%
print("2. Best Model saved as 'diabetes_model.pkl'")
# Out:
# 2. Best Model saved as 'diabetes_model.pkl'

# %%
if os.path.exists('diabetes_model.pkl') and os.path.exists('diabetes_preprocessor.pkl'):
    print("\n SUCCESS : Both files saved successfully. You may close this notebook. ")
else:
    print("\n ERROR : Something went wrong.  Files not found!")
# Out:
#  SUCCESS : Both files saved successfully. You may close this notebook.

# %%
defaults = {}

for col in X.columns:
    if (X[col].dtype == "object"):
        defaults[col] = X[col].mode()[0]

    else:
        defaults[col] = X[col].median()

print("=" * 30)
print(defaults)
print("=" * 30)
# Out:
# ==============================
# {'age': 50.0, 'gender': 'Female', 'ethnicity': 'White', 'education_level': 'Highschool', 'income_level': 'Middle', 'employment_status': 'Employed', 'smoking_status': 'Never', 'alcohol_consumption_per_week': 2.0, 'physical_activity_minutes_per_week': 100.0, 'diet_score': 6.0, 'sleep_hours_per_day': 7.0, 'screen_time_hours_per_day': 6.0, 'family_history_diabetes': 0.0, 'hypertension_history': 0.0, 'cardiovascular_history': 0.0, 'bmi': 25.6, 'waist_to_hip_ratio': 0.86, 'systolic_bp': 116.0, 'diastolic_bp': 75.0, 'heart_rate': 70.0, 'cholesterol_total': 186.0, 'hdl_cholesterol': 54.0, 'ldl_cholesterol': 102.0, 'triglycerides': 121.0, 'glucose_fasting': 111.0, 'glucose_postprandial': 160.0, 'insulin_level': 8.79, 'hba1c': 6.52}
# ==============================
