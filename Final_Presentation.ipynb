# %%
import joblib
import pandas as pd
import numpy as np
import warnings

# %%
df1 = pd.read_csv('diabetes_dataset.csv')

# %%
df1.head(20)
# Out:
#     age  gender ethnicity education_level  income_level employment_status  \
# 0    58    Male     Asian      Highschool  Lower-Middle          Employed
# 1    48  Female     White      Highschool        Middle          Employed
# 2    60    Male  Hispanic      Highschool        Middle        Unemployed
# 3    74  Female     Black      Highschool           Low           Retired
# 4    46    Male     White        Graduate        Middle           Retired
# 5    46  Female     White      Highschool  Upper-Middle          Employed
# 6    75  Female     White        Graduate  Upper-Middle           Retired
# 7    62    Male     White    Postgraduate        Middle        Unemployed
# 8    42    Male     Black      Highschool  Lower-Middle          Employed
# 9    59  Female     White        Graduate        Middle          Employed
# 10   43  Female     White      Highschool        Middle          Employed
# 11   43  Female     White      Highschool        Middle          Employed
# ...

# %%
warnings.filterwarnings('ignore')

# %%
print("Inityializing Diabetes Prediction System...")
# Out:
# Inityializing Diabetes Prediction System...

# %%
import joblib
import pandas as pd
import warnings
warnings.filterwarnings('ignore')


loaded_preprocessor = joblib.load('diabetes_preprocessor.pkl')
loaded_model = joblib.load('diabetes_model.pkl')

def quick_predict():
    print("DIABETES RAPID PREDICTION")
    
    
    patient_data = {
        'age': 50.0,
        'gender': 'Female',
        'ethnicity': 'White',
        'education_level': 'Highschool',
        'income_level': 'Middle',
        'employment_status': 'Employed',
        'smoking_status': 'Never',
        'alcohol_consumption_per_week': 2.0,
        'physical_activity_minutes_per_week': 100.0,
        'diet_score': 6.0, 'sleep_hours_per_day': 7.0,
        'screen_time_hours_per_day': 6.0,
        'family_history_diabetes': 0.0,
        'hypertension_history': 0.0,
        'cardiovascular_history': 0.0,
        'bmi': 25.6,
        'waist_to_hip_ratio': 0.86,
        'systolic_bp': 116.0,
        'diastolic_bp': 75.0,
        'heart_rate': 70.0,
        'cholesterol_total': 186.0,
        'hdl_cholesterol': 54.0,
        'ldl_cholesterol': 102.0,
        'triglycerides': 121.0,
        'glucose_fasting': 111.0,
        'glucose_postprandial': 160.0,
        'insulin_level': 8.79,
        'hba1c': 6.52}
    
    
    
    print("Enter key patient metrics (Press Enter to keep default):")

    for key , default_value in patient_data.items():
        value = input(f"{key.capitalize()} [{default_value}]")

        if value.strip() != "":
            try:
                patient_data[key]=float(value)
            except:
                patient_data[key] = value
   
    df_input = pd.DataFrame([patient_data])
    
    print("\nProcessing...")
    processed_data = loaded_preprocessor.transform(df_input)
    prediction = loaded_model.predict(processed_data)
    
    if prediction[0] == 1:
        print(">>> RESULT: High Risk of Diabetes")
    else:
        print(">>> RESULT: Low Risk of Diabetes")

quick_predict()
# Out:
# DIABETES RAPID PREDICTION
# Enter key patient metrics (Press Enter to keep default):
# Age [50.0] 40
# Gender [Female] Male
# Ethnicity [White] Asian
# Education_level [Highschool] Graduate
# Income_level [Middle] High
# Employment_status [Employed] Employed
# Smoking_status [Never] Current
# Alcohol_consumption_per_week [2.0] 7
# Physical_activity_minutes_per_week [100.0] 0
# Diet_score [6.0] 8
# Sleep_hours_per_day [7.0] 6
# Screen_time_hours_per_day [6.0] 6
# Family_history_diabetes [0.0] no
# Hypertension_history [0.0] 0
# Cardiovascular_history [0.0] 5
# Bmi [25.6] 25
# Waist_to_hip_ratio [0.86] 1
# Systolic_bp [116.0] 110
# Diastolic_bp [75.0] 80
# Heart_rate [70.0] 90
# Cholesterol_total [186.0] 150
# Hdl_cholesterol [54.0] 250
# Ldl_cholesterol [102.0] 90
# Triglycerides [121.0] 115
# Glucose_fasting [111.0] 100
# Glucose_postprandial [160.0] 155
# Insulin_level [8.79] 8
# Hba1c [6.52] 3
# Processing...
# ...
